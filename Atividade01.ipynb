# %% [markdown]
# <a href="https://colab.research.google.com/github/Johndz9/atividades-python/blob/main/Atividade01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))
if idade>= 18:
  print("Pode dirigir!")
else:
  print("Não pode dirigir!")
# Out:
# Digite sua idade: 19
# Pode dirigir!

# %%
operacao=str(input("Digite uma operação: '+', '-': "))
num1=int(input("Digite o primeiro número: "))
num2=int(input("Digite o segundo número: "))
print("O resultado é: ")
if operacao=='+':
  print(num1 + num2)
elif operacao=='-':
  print(num1 - num2)
# Out:
# Digite uma operação: '+', '-': -
# Digite o primeiro número: 12
# Digite o segundo número: 2
# O resultado é:
# 10

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

soma = num1 + num2

print("o resultado da soma é:  ", soma)
# Out:
# Digite o primeiro número: 1
# Digite o segundo número: 1
# o resultado da soma é:   2.0

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:", soma)
# Out:
# Resultado: 30

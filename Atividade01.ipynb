# %% [markdown]
# <a href="https://colab.research.google.com/github/Johndz9/atividades-python/blob/main/Atividade01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 01 — Introdução ao Python

# %%
print("Minha primeira atividade no Google Colab")
print("Aprendendo Python e GitHub")
# Out:
# Minha primeira atividade no Google Colab
# Aprendendo Python e GitHub

# %% [markdown]
# ##Programa de entrada de dados
#
# ---

# %%
disciplina = str(input("Informe o nome da sua disciplina: \n"))
conteudo = str(input("Informe o conteúdo da sua disciplina: \n"))
print("--- INFORMAÇÕES DA ATIVIDADE ---")
print("Sua disciplina é: \n",(disciplina))
print("E seu conteúdo é: \n",(conteudo))
# Out:
# Informe o nome da sua disciplina:
# matematica
# Informe o conteúdo da sua disciplina:
# função afim
# --- INFORMAÇÕES DA ATIVIDADE ---
# Sua disciplina é:
#  matematica
# E seu conteúdo é:
#  função afim

# %% [markdown]
# ##Atividade desafio
#
# ---

# %%
print("Aprendendo versionamento de projetos!")
# Out:
# Aprendendo versionamento de projetos!
